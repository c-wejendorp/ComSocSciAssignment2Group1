# %%
import pandas as pd
import networkx as nx
import numpy as np
from networkx.readwrite import json_graph
import json
import scipy 
import netwulf as nw
from netwulf import visualize
import random
from scipy.stats import sem, t
import matplotlib.pyplot as plt

# %% [markdown]
# The following cell loads the data and displays the total number of nodes in the graph after the giant connected component (GCC) has been extracted

# %%
f = open('data/graph.json')
data = json.load(f)
G = nx.node_link_graph(data) 
print(f"The number of nodes before the GCC has been found: {len(list(G.nodes))}")
largest_cc = max(nx.connected_components(G), key=len)
# update graph to only include the larget connected component. 
G = G.subgraph(largest_cc)
print(f"The number of nodes after the GCC has been found: {len(list(G.nodes))}")
# Out:
# The number of nodes before the GCC has been found: 2162
# The number of nodes after the GCC has been found: 1271

# %% [markdown]
# Exercise 1.1:
# For each node, compute the fraction of edges that connect to a node that works in the same top field. Find the average value across all nodes:
#
# In the cell below a function is defined that does exactly that.
# When executed on our graph we get the value printed below:

# %%
# loop over all nodes and for each node save the number of edges leading to a node with the same top field.
def fracOfNbrsSameTopic(graph):
    for node in list(graph.nodes):
        nodeTopField=graph.nodes[node]['field']
        counter=0
        for nbr in graph.adj[node]:
            nbrTopField=graph.nodes[nbr]['field']
            if nodeTopField == nbrTopField:
                counter+=1        
        fracOfNbrsSameTopic=counter/len(graph.adj[node])    
        graph.nodes[node]['fracOfNbrsSameTopic']=fracOfNbrsSameTopic
        
    _,values = zip(*list(graph.nodes.data('fracOfNbrsSameTopic')))
    AvgValue=sum(values)/len(list(graph.nodes))
    return AvgValue

print(f"The average value across all nodes is:  {fracOfNbrsSameTopic(G)}")
# Out:
# The average value across all nodes is:  0.3782870230873379

# %% [markdown]
# Exercise 1.2: Create a new graph, with the same nodes and edges, but where the association between nodes and field is shuffled. Compute the measure above for this randomized graph.
#
# The cell below defines a function that takes a graph as input and the extracts all the nodes' "field" attributes and reassign them randomly.
# If we do this we get the value printed below:

# %%
def shuffleNodeFields(graph):
    shuffledGraph=graph.copy()    
    key,values = zip(*list(shuffledGraph.nodes.data('field')))    
    values=list(values)    
    random.shuffle(values)    
    newDict = dict(zip(key,values))
    nx.set_node_attributes(shuffledGraph, newDict, name="field")

    #print(shuffledGraph.nodes.data('field'))
    return shuffledGraph

print(f"The average value across all nodes in the randomized graph is:  {fracOfNbrsSameTopic(shuffleNodeFields(G))}")
# Out:
# The average value across all nodes in the randomized graph is:  0.2506501723868497

# %% [markdown]
# Exercise 1.3: Repeat the point above 100 times (at least). Plot the distribution of the values obtained and compare it with the value you have found for the real graph. Is the chance to connect to a member of the same field significantly higher than it would be by chance?
#
# To solve this question we used bootstrapping. Based on a significance level of 0.05 we conclude the chance of connecting to a member of the same field is significantly higher than it would be by chance. The calculations can see below and the p-value is printed.

# %%
n=500
sampleValues=[fracOfNbrsSameTopic(shuffleNodeFields(G)) for i in range(n)]
stdError=sem(sampleValues)
sigLevel = 0.05


p_value = (np.sum(np.abs(null_dist) >= np.abs(alternative_hypothesis)) + 1) / (n_bootstraps + 1)

# %%
num_bins = 20
n, bins, patches = plt.hist(sampleValues, num_bins, facecolor='blue', alpha=0.5)
plt.show()

# %%
fracOfNbrsSameTopic(G)
new=shuffleNodeFields(G)
print(G.nodes.data('field'))
print(fracOfNbrsSameTopic(G))
print(new.nodes.data('field'))
print(fracOfNbrsSameTopic(new))
# Out:
# [('2101037', 'Computer Science'), ('3001795', 'Computer Science'), ('2080155085', 'Business'), ('33570565', 'Psychology'), ('66118125', 'Computer Science'), ('153503994', 'Sociology'), ('48265513', 'Economics'), ('46417808', 'Computer Science'), ('2538277', 'Computer Science'), ('1729484', 'Computer Science'), ('98808950', 'Computer Science'), ('51040873', 'Computer Science'), ('145059556', 'Law'), ('1389955131', 'Biology'), ('119151277', 'Psychology'), ('96893747', 'Law'), ('30421024', 'Psychology'), ('2871138', 'Law'), ('2020262166', 'Psychology'), ('2349638', 'Economics'), ('151377924', 'Law'), ('151463421', 'Law'), ('2088358', 'Computer Science'), ('6673771', 'Psychology'), ('97678793', 'Sociology'), ('1395385575', 'Political Science'), ('26435264', 'Political Science'), ('145212340', 'Psychology'), ('32216871', 'Sociology'), ('49305855', 'Computer Science'), ('47205422', 'Biology'), ('51435753', 'Computer Science'), ('2557324', 'Computer Science'), ('52229695', 'Economics'), ('151467651', 'Medicine'), ('1743706', 'Computer Science'), ('2255094', 'Computer Science'), ('3145906', 'Computer Science'), ('1682773', 'Computer Science'), ('4462678', 'Economics'), ('2254522', 'Computer Science'), ('1715670', 'Computer Science'), ('2202643918', 'Sociology'), ('1684412', 'Computer Science'), ('2698329', 'Computer Science'), ('34893194', 'Computer Science'), ('1769960', 'Computer Science'), ('3118802', 'Computer Science'), ('143653472', 'Computer Science'), ('2061878581', 'Psychology'), ('1403820241', 'Computer Science'), ('2617057', 'Computer Science'), ('3329961', 'Computer Science'), ('144684950', 'Computer Science'), ('145190501', 'Computer Science'), ('2091576379', 'Political Science'), ('2381124', 'Psychology'), ('2080197097', 'Political Science'), ('2592694', 'Computer Science'), ('144626725', 'Computer Science'), ('34616778', 'Computer Science'), ('2088546758', 'Computer Science'), ('145519038', 'Psychology'), ('1684687', 'Computer Science'), ('113332048', 'History'), ('2209502019', 'Economics'), ('48133385', 'Economics'), ('48866094', 'Psychology'), ('1678460', 'Medicine'), ('1760810', 'Computer Science'), ('35168570', 'Computer Science'), ('2078464034', 'Political Science'), ('145148025', 'Economics'), ('35167554', 'Computer Science'), ('2023275', 'Sociology'), ('144300761', 'Computer Science'), ('1767493', 'Computer Science'), ('2504674', 'Medicine'), ('1999125', 'Computer Science'), ('104942679', 'Political Science'), ('1703601', 'Computer Science'), ('2251027', 'Computer Science'), ('1744110', 'Computer Science'), ('145375801', 'Computer Science'), ('41192561', 'Materials Science'), ('3086323', 'Economics'), ('40315411', 'Computer Science'), ('145709776', 'Computer Science'), ('47538483', 'Computer Science'), ('2002210', 'Computer Science'), ('1705156', 'Computer Science'), ('34627491', 'Computer Science'), ('107975119', 'Economics'), ('1396564179', 'Medicine'), ('123466322', 'Computer Science'), ('79774420', 'Computer Science'), ('2202771824', 'Political Science'), ('1785423162', 'Computer Science'), ('1693341', 'Computer Science'), ('2152662507', 'Political Science'), ('1685102', 'Computer Science'), ('3306947', 'Economics'), ('145512648', 'Computer Science'), ('47193909', 'Economics'), ('2069995475', 'Political Science'), ('2862768', 'Economics'), ('2016371', 'Psychology'), ('1692062', 'Computer Science'), ('2070409893', 'Political Science'), ('84482743', 'Agricultural And Food Sciences'), ('2149740', 'Economics'), ('2561756', 'Computer Science'), ('4410019', 'Computer Science'), ('1978063933', 'Economics'), ('40025432', 'Economics'), ('2059894216', 'Computer Science'), ('34702580', 'Computer Science'), ('2724666', 'Business'), ('145392527', 'Computer Science'), ('3261461', 'Computer Science'), ('1783512', 'Economics'), ('2136708', 'Computer Science'), ('38816148', 'Medicine'), ('144558957', 'Education'), ('1769221', 'Mathematics'), ('2111373038', 'Economics'), ('144656270', 'Computer Science'), ('84222746', 'Economi ...
# 0.3782870230873379
# [('2101037', 'Materials Science'), ('3001795', 'Political Science'), ('2080155085', 'Computer Science'), ('33570565', 'Political Science'), ('66118125', 'Computer Science'), ('153503994', 'Education'), ('48265513', 'Computer Science'), ('46417808', 'Education'), ('2538277', 'Computer Science'), ('1729484', 'Business'), ('98808950', 'Medicine'), ('51040873', 'Computer Science'), ('145059556', 'Engineering'), ('1389955131', 'Political Science'), ('119151277', 'Computer Science'), ('96893747', 'Economics'), ('30421024', 'Sociology'), ('2871138', 'Computer Science'), ('2020262166', 'Medicine'), ('2349638', 'Computer Science'), ('151377924', 'Computer Science'), ('151463421', 'Computer Science'), ('2088358', 'Philosophy'), ('6673771', 'Political Science'), ('97678793', 'Education'), ('1395385575', 'Political Science'), ('26435264', 'Political Science'), ('145212340', 'Computer Science'), ('32216871', 'Economics'), ('49305855', 'Business'), ('47205422', 'Computer Science'), ('51435753', 'Economics'), ('2557324', 'Computer Science'), ('52229695', 'Computer Science'), ('151467651', 'Business'), ('1743706', 'Business'), ('2255094', 'Computer Science'), ('3145906', 'Economics'), ('1682773', 'Business'), ('4462678', 'Political Science'), ('2254522', 'Political Science'), ('1715670', 'Physics'), ('2202643918', 'Computer Science'), ('1684412', 'Sociology'), ('2698329', 'Medicine'), ('34893194', 'Economics'), ('1769960', 'Computer Science'), ('3118802', 'Economics'), ('143653472', 'Computer Science'), ('2061878581', 'Business'), ('1403820241', 'Political Science'), ('2617057', 'Sociology'), ('3329961', 'Psychology'), ('144684950', 'Computer Science'), ('145190501', 'Psychology'), ('2091576379', 'Economics'), ('2381124', 'Economics'), ('2080197097', 'Education'), ('2592694', 'Computer Science'), ('144626725', 'Computer Science'), ('34616778', 'Economics'), ('2088546758', 'Computer Science'), ('145519038', 'Political Science'), ('1684687', 'Computer Science'), ('113332048', 'Economics'), ('2209502019', 'Economics'), ('48133385', 'Sociology'), ('48866094', 'Computer Science'), ('1678460', 'Economics'), ('1760810', 'Political Science'), ('35168570', 'Computer Science'), ('2078464034', 'Computer Science'), ('145148025', 'Political Science'), ('35167554', 'Medicine'), ('2023275', 'Medicine'), ('144300761', 'Computer Science'), ('1767493', 'Computer Science'), ('2504674', 'Environmental Science'), ('1999125', 'Computer Science'), ('104942679', 'Economics'), ('1703601', 'Computer Science'), ('2251027', 'Business'), ('1744110', 'Computer Science'), ('145375801', 'Medicine'), ('41192561', 'Computer Science'), ('3086323', 'Sociology'), ('40315411', 'Computer Science'), ('145709776', 'Law'), ('47538483', 'Psychology'), ('2002210', 'Computer Science'), ('1705156', 'Sociology'), ('34627491', 'Political Science'), ('107975119', 'Computer Science'), ('1396564179', 'Computer Science'), ('123466322', 'Computer Science'), ('79774420', 'Economics'), ('2202771824', 'Economics'), ('1785423162', 'Computer Science'), ('1693341', 'Computer Science'), ('2152662507', 'Political Science'), ('1685102', 'Sociology'), ('3306947', 'Sociology'), ('145512648', 'Environmental Science'), ('47193909', 'Economics'), ('2069995475', 'Agricultural And Food Sciences'), ('2862768', 'Economics'), ('2016371', 'Computer Science'), ('1692062', 'Computer Science'), ('2070409893', 'Computer Science'), ('84482743', 'Medicine'), ('2149740', 'Economics'), ('2561756', 'Political Science'), ('4410019', 'Computer Science'), ('1978063933', 'Computer Science'), ('40025432', 'Computer Science'), ('2059894216', 'Computer Science'), ('34702580', 'Law'), ('2724666', 'Education'), ('145392527', 'Economics'), ('3261461', 'Political Science'), ('1783512', 'Computer Science'), ('2136708', 'Computer Science'), ('38816148', 'Computer Science'), ('144558957', 'Environmental Science'), ('1769221', 'Political Science'), ('2111373038', 'Economics'), ('144656270', 'Psychology'), ('84222746', 'Computer Science') ...
# 0.24979915675894898

# %%
G.nodes["35167554"]
# Out:
# {'field': 'Computer Science',
#  'name': 'Lorenzo Gatti',
#  'citation_count': 1.0,
#  'num_ccs_papers': 2,
#  'first_css_paper_year': 2021.0,
#  'fracOfNbrsSameTopic': 0.5}

# %%
G.nodes(data='fracOfNbrsSameTopic')
# Out:
# NodeDataView({'2101037': 0.6, '3001795': 1.0, '2080155085': 0.0, '33570565': 0.0, '66118125': 0.6666666666666666, '153503994': 0.0, '48265513': 0.0, '46417808': 0.75, '2538277': 1.0, '1729484': 1.0, '98808950': 0.75, '51040873': 0.10526315789473684, '145059556': 0.25, '1389955131': 0.0, '119151277': 0.2, '96893747': 0.6, '30421024': 0.3333333333333333, '2871138': 0.0, '2020262166': 0.2, '2349638': 0.0, '151377924': 0.6, '151463421': 0.375, '2088358': 0.25, '6673771': 0.0, '97678793': 0.0, '1395385575': 0.0, '26435264': 0.0, '145212340': 0.3333333333333333, '32216871': 0.0, '49305855': 0.6153846153846154, '47205422': 0.0, '51435753': 0.25, '2557324': 0.16666666666666666, '52229695': 0.0, '151467651': 0.0, '1743706': 0.3333333333333333, '2255094': 0.35, '3145906': 0.5, '1682773': 0.5925925925925926, '4462678': 0.0, '2254522': 1.0, '1715670': 0.4, '2202643918': 0.0, '1684412': 0.5714285714285714, '2698329': 0.7, '34893194': 1.0, '1769960': 0.7142857142857143, '3118802': 1.0, '143653472': 0.7777777777777778, '2061878581': 0.0, '1403820241': 1.0, '2617057': 1.0, '3329961': 0.3448275862068966, '144684950': 0.6666666666666666, '145190501': 1.0, '2091576379': 0.25, '2381124': 0.0, '2080197097': 0.25, '2592694': 0.7894736842105263, '144626725': 1.0, '34616778': 1.0, '2088546758': 0.625, '145519038': 0.045454545454545456, '1684687': 0.21428571428571427, '113332048': 0.0, '2209502019': 0.16666666666666666, '48133385': 0.16666666666666666, '48866094': 0.2, '1678460': 0.0, '1760810': 0.5, '35168570': 0.5555555555555556, '2078464034': 0.0, '145148025': 0.0, '35167554': 0.5, '2023275': 0.0, '144300761': 0.0, '1767493': 0.625, '2504674': 0.05555555555555555, '1999125': 0.5, '104942679': 0.0, '1703601': 0.5714285714285714, '2251027': 0.09090909090909091, '1744110': 0.5, '145375801': 0.6666666666666666, '41192561': 0.0, '3086323': 0.0, '40315411': 1.0, '145709776': 1.0, '47538483': 0.5, '2002210': 1.0, '1705156': 0.47058823529411764, '34627491': 0.4166666666666667, '107975119': 0.0, '1396564179': 0.0, '123466322': 0.6666666666666666, '79774420': 0.6666666666666666, '2202771824': 0.0, '1785423162': 0.6666666666666666, '1693341': 0.8, '2152662507': 0.0, '1685102': 0.875, '3306947': 0.0, '145512648': 0.2222222222222222, '47193909': 0.2727272727272727, '2069995475': 0.3333333333333333, '2862768': 0.0, '2016371': 0.15384615384615385, '1692062': 0.3333333333333333, '2070409893': 0.3333333333333333, '84482743': 0.0, '2149740': 0.4, '2561756': 0.6666666666666666, '4410019': 0.5, '1978063933': 0.25, '40025432': 0.16666666666666666, '2059894216': 0.6, '34702580': 0.5, '2724666': 0.125, '145392527': 0.6, '3261461': 0.7, '1783512': 0.375, '2136708': 0.75, '38816148': 0.0, '144558957': 0.0, '1769221': 0.0, '2111373038': 0.6666666666666666, '144656270': 0.3333333333333333, '84222746': 0.6666666666666666, '2793618': 0.3333333333333333, '1898789': 0.6, '2400779': 0.6, '144373940': 0.0, '144027066': 0.0, '2136396863': 0.0, '144633779': 0.0, '144182945': 0.75, '3071703': 0.2, '50667617': 0.5, '15280578': 0.2857142857142857, '1996878': 0.2857142857142857, '1726531': 0.0, '115938433': 0.2, '49367064': 0.4375, '1403025860': 1.0, '144327744': 0.5, '143782314': 1.0, '3233888': 0.25, '2069874449': 0.0, '36517276': 0.4444444444444444, '2277974': 0.0, '2180879': 0.0, '39634853': 0.0, '1572994868': 0.2857142857142857, '147851692': 0.75, '1752285757': 0.4, '2111720': 0.1875, '1752307775': 0.4, '1572291266': 0.4, '1752287104': 0.5454545454545454, '118830067': 0.0, '1484533262': 0.6666666666666666, '120935900': 0.5714285714285714, '1390547809': 0.75, '2047003791': 0.75, '87465347': 0.0, '1734731': 0.5714285714285714, '144300729': 1.0, '151203958': 0.16666666666666666, '2093924254': 0.6, '2146465902': 0.6666666666666666, '2047998583': 0.6, '41072903': 0.6923076923076923, '2047999838': 0.5, '2101297': 0.4, '2061295549': 0.2, '118982086': 0.5, '2109039239': 0.4, '47073608': 0.4, '146721686': 0.6, '2109670297': 0.5, '143990839': 0.5, '3086996': 0.5, '2159201633': 0.666666666666 ...

# %% [markdown]
# G.nodes.data('fracOfNbrsSameTopic')
